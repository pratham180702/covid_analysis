# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('vaccinations.csv')

# %%
df
# Out:
#            location iso_code        date  total_vaccinations  \
# 0       Afghanistan      AFG  2021-02-22                 0.0
# 1       Afghanistan      AFG  2021-02-23                 NaN
# 2       Afghanistan      AFG  2021-02-24                 NaN
# 3       Afghanistan      AFG  2021-02-25                 NaN
# 4       Afghanistan      AFG  2021-02-26                 NaN
# ...             ...      ...         ...                 ...
# 156513     Zimbabwe      ZWE  2022-10-05          12219760.0
# 156514     Zimbabwe      ZWE  2022-10-06                 NaN
# 156515     Zimbabwe      ZWE  2022-10-07                 NaN
# 156516     Zimbabwe      ZWE  2022-10-08                 NaN
# 156517     Zimbabwe      ZWE  2022-10-09          12222754.0
#
#         people_vaccinated  people_fully_vaccinated  total_boosters  \
# 0                     0.0                      NaN             NaN
# 1                     NaN                      NaN             NaN
# ...

# %%
total_vaccinations_by_location = df.groupby('location')['people_fully_vaccinated'].sum()

# %%
total_vaccinations_by_location
# Out:
# location
# Afghanistan          4.689122e+08
# Africa               1.279220e+11
# Albania              1.600763e+08
# Algeria              1.181399e+08
# Andorra              1.824481e+06
#                          ...
# Wallis and Futuna    1.743710e+05
# World                2.468602e+12
# Yemen                1.229150e+07
# Zambia               3.822371e+08
# Zimbabwe             1.286931e+09
# Name: people_fully_vaccinated, Length: 235, dtype: float64

# %%
tf = total_vaccinations_by_location.reset_index().rename(columns={'total_vaccinations': 'total_vaccinations_by_location'})

# %%
tf
# Out:
#               location  people_fully_vaccinated
# 0          Afghanistan             4.689122e+08
# 1               Africa             1.279220e+11
# 2              Albania             1.600763e+08
# 3              Algeria             1.181399e+08
# 4              Andorra             1.824481e+06
# ..                 ...                      ...
# 230  Wallis and Futuna             1.743710e+05
# 231              World             2.468602e+12
# 232              Yemen             1.229150e+07
# 233             Zambia             3.822371e+08
# 234           Zimbabwe             1.286931e+09
#
# [235 rows x 2 columns]

# %%
df = pd.read_csv('covid_worldwide.csv')

# %%
tf_final = tf.reset_index().rename(columns={'location': 'Country'})

# %%
tf_final
# Out:
#      index            Country  people_fully_vaccinated
# 0        0        Afghanistan             4.689122e+08
# 1        1             Africa             1.279220e+11
# 2        2            Albania             1.600763e+08
# 3        3            Algeria             1.181399e+08
# 4        4            Andorra             1.824481e+06
# ..     ...                ...                      ...
# 230    230  Wallis and Futuna             1.743710e+05
# 231    231              World             2.468602e+12
# 232    232              Yemen             1.229150e+07
# 233    233             Zambia             3.822371e+08
# 234    234           Zimbabwe             1.286931e+09
#
# [235 rows x 3 columns]

# %%
merged_df = pd.merge(df, tf_final, on='Country')

# %%
merged_df
# Out:
#      Serial Number           Country Total Cases Total Deaths Total Recovered  \
# 0                2             India  44,682,784      530,740      44,150,289
# 1                3            France  39,524,311      164,233      39,264,546
# 2                4           Germany  37,779,833      165,711      37,398,100
# 3                5            Brazil  36,824,580      697,074      35,919,372
# 4                6             Japan  32,588,442       68,399      21,567,425
# ..             ...               ...         ...          ...             ...
# 194            223      Saint Helena       2,166          NaN               2
# 195            224  Falkland Islands       1,930          NaN           1,930
# 196            225        Montserrat       1,403            8           1,376
# 197            226              Niue         747          NaN             746
# 198            231           Tokelau           5          NaN             NaN
#
# ...

# %%
df_final = merged_df.reset_index().rename(columns={'people_fully_vaccinated': 'vaccination'})

# %%
df_final
# Out:
#      level_0  Serial Number           Country Total Cases Total Deaths  \
# 0          0              2             India  44,682,784      530,740
# 1          1              3            France  39,524,311      164,233
# 2          2              4           Germany  37,779,833      165,711
# 3          3              5            Brazil  36,824,580      697,074
# 4          4              6             Japan  32,588,442       68,399
# ..       ...            ...               ...         ...          ...
# 194      194            223      Saint Helena       2,166          NaN
# 195      195            224  Falkland Islands       1,930          NaN
# 196      196            225        Montserrat       1,403            8
# 197      197            226              Niue         747          NaN
# 198      198            231           Tokelau           5          NaN
#
#     Total Recovered Active Cases   Total Test     Population  index  \
# ...

# %%
df_final['vaccination'] = (df_final['vaccination'] / 1000000).astype(int)

# %%
df_final
# Out:
#      level_0  Serial Number           Country Total Cases Total Deaths  \
# 0          0              2             India  44,682,784      530,740
# 1          1              3            France  39,524,311      164,233
# 2          2              4           Germany  37,779,833      165,711
# 3          3              5            Brazil  36,824,580      697,074
# 4          4              6             Japan  32,588,442       68,399
# ..       ...            ...               ...         ...          ...
# 194      194            223      Saint Helena       2,166          NaN
# 195      195            224  Falkland Islands       1,930          NaN
# 196      196            225        Montserrat       1,403            8
# 197      197            226              Niue         747          NaN
# 198      198            231           Tokelau           5          NaN
#
#     Total Recovered Active Cases   Total Test     Population  index  \
# ...

# %%
test = pd.read_csv('current-global.csv')
test
# Out:
#       id  population          name  dosesAdministered  peopleVaccinated  \
# 0    ABW    111000.0         Aruba             173365           89790.0
# 1    AFG  32941000.0   Afghanistan           11820186        10873999.0
# 2    AGO  31031000.0        Angola           22297104        14220830.0
# 3    AIA     15000.0      Anguilla              24102           10846.0
# 4    ALB   2878000.0       Albania            2966256         1335654.0
# ..   ...         ...           ...                ...               ...
# 218  WSM    198000.0         Samoa             516744          191052.0
# 219  YEM  32471000.0         Yemen             898257          730429.0
# 220  ZAF  59622000.0  South Africa           37587301        23056702.0
# 221  ZMB  18882000.0        Zambia            9202035         7876354.0
# 222  ZWE  15189000.0      Zimbabwe           12381059         6468966.0
#
#      completedVaccination  boosterDosesAdministered
# ...

# %%
df
# Out:
#      Serial Number           Country  Total Cases Total Deaths  \
# 0                1               USA  104,196,861    1,132,935
# 1                2             India   44,682,784      530,740
# 2                3            France   39,524,311      164,233
# 3                4           Germany   37,779,833      165,711
# 4                5            Brazil   36,824,580      697,074
# ..             ...               ...          ...          ...
# 226            227  Diamond Princess          712           13
# 227            228      Vatican City           29          NaN
# 228            229    Western Sahara           10            1
# 229            230        MS Zaandam            9            2
# 230            231           Tokelau            5          NaN
#
#     Total Recovered Active Cases     Total Test     Population
# 0       101,322,779    1,741,147  1,159,832,679    334,805,269
# 1        44,150,289        1,755    915,265,788  1,406,631,776
# ...

# %%
test1 = test.reset_index().rename(columns={'name': 'Country'})

# %%
test1
# Out:
#      index   id  population       Country  dosesAdministered  \
# 0        0  ABW    111000.0         Aruba             173365
# 1        1  AFG  32941000.0   Afghanistan           11820186
# 2        2  AGO  31031000.0        Angola           22297104
# 3        3  AIA     15000.0      Anguilla              24102
# 4        4  ALB   2878000.0       Albania            2966256
# ..     ...  ...         ...           ...                ...
# 218    218  WSM    198000.0         Samoa             516744
# 219    219  YEM  32471000.0         Yemen             898257
# 220    220  ZAF  59622000.0  South Africa           37587301
# 221    221  ZMB  18882000.0        Zambia            9202035
# 222    222  ZWE  15189000.0      Zimbabwe           12381059
#
#      peopleVaccinated  completedVaccination  boosterDosesAdministered
# 0             89790.0               83575.0                       NaN
# 1          10873999.0            10105500.0                       NaN
# ...

# %%
test2 = test1[['Country','completedVaccination']]
test2
# Out:
#           Country  completedVaccination
# 0           Aruba               83575.0
# 1     Afghanistan            10105500.0
# 2          Angola             7814121.0
# 3        Anguilla               10314.0
# 4         Albania             1261243.0
# ..            ...                   ...
# 218         Samoa              177456.0
# 219         Yemen              470491.0
# 220  South Africa            19377183.0
# 221        Zambia             5926723.0
# 222      Zimbabwe             5912093.0
#
# [223 rows x 2 columns]

# %%
test_merged_df = pd.merge(df, test2 , on='Country')
test_merged_df
# Out:
#      Serial Number                Country Total Cases Total Deaths  \
# 0                2                  India  44,682,784      530,740
# 1                3                 France  39,524,311      164,233
# 2                4                Germany  37,779,833      165,711
# 3                5                 Brazil  36,824,580      697,074
# 4                6                  Japan  32,588,442       68,399
# ..             ...                    ...         ...          ...
# 182            213  Sao Tome and Principe       6,280           77
# 183            217                  Nauru       4,621            1
# 184            218               Anguilla       3,904           12
# 185            224       Falkland Islands       1,930          NaN
# 186            225             Montserrat       1,403            8
#
#     Total Recovered Active Cases   Total Test     Population  \
# 0        44,150,289        1,755  915,265,788  1,406,631,776
# ...
