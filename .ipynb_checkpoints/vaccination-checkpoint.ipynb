# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('vaccinations.csv')

# %%
df
# Out:
#            location iso_code        date  total_vaccinations  \
# 0       Afghanistan      AFG  2021-02-22                 0.0
# 1       Afghanistan      AFG  2021-02-23                 NaN
# 2       Afghanistan      AFG  2021-02-24                 NaN
# 3       Afghanistan      AFG  2021-02-25                 NaN
# 4       Afghanistan      AFG  2021-02-26                 NaN
# ...             ...      ...         ...                 ...
# 156513     Zimbabwe      ZWE  2022-10-05          12219760.0
# 156514     Zimbabwe      ZWE  2022-10-06                 NaN
# 156515     Zimbabwe      ZWE  2022-10-07                 NaN
# 156516     Zimbabwe      ZWE  2022-10-08                 NaN
# 156517     Zimbabwe      ZWE  2022-10-09          12222754.0
#
#         people_vaccinated  people_fully_vaccinated  total_boosters  \
# 0                     0.0                      NaN             NaN
# 1                     NaN                      NaN             NaN
# 2                     NaN                      NaN             NaN
# 3                     NaN                      NaN             NaN
# 4                     NaN                      NaN             NaN
# ...                   ...                      ...             ...
# 156513          6436704.0                4750104.0       1032952.0
# 156514                NaN                      NaN             NaN
# 156515                NaN                      NaN             NaN
# 156516                NaN                      NaN             NaN
# 156517          6437808.0                4751270.0       1033676.0
#
#         daily_vaccinations_raw  daily_vaccinations  \
# 0                          NaN                 NaN
# 1                          NaN              1367.0
# 2                          NaN              1367.0
# 3                          NaN              1367.0
# 4                          NaN              1367.0
# ...                        ...                 ...
# 156513                     NaN              2076.0
# 156514                     NaN              1714.0
# 156515                     NaN              1529.0
# 156516                     NaN              1344.0
# 156517                     NaN              1126.0
#
#         total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                                 0.00                           0.00
# 1                                  NaN                            NaN
# 2                                  NaN                            NaN
# 3                                  NaN                            NaN
# 4                                  NaN                            NaN
# ...                                ...                            ...
# 156513                           74.87                          39.44
# 156514                             NaN                            NaN
# 156515                             NaN                            NaN
# 156516                             NaN                            NaN
# 156517                           74.89                          39.45
#
#         people_fully_vaccinated_per_hundred  total_boosters_per_hundred  \
# 0                                       NaN                         NaN
# 1                                       NaN                         NaN
# 2                                       NaN                         NaN
# 3                                       NaN                         NaN
# 4                                       NaN                         NaN
# ...                                     ...                         ...
# 156513                                29.11                        6.33
# 156514                                  NaN                         NaN
# 156515                                  NaN                         NaN
# 156516                                  NaN                         NaN
# 156517                                29.11                        6.33
#
#         daily_vaccinations_per_million  daily_people_vaccinated  \
# 0                                  NaN                      NaN
# 1                                 33.0                   1367.0
# 2                                 33.0                   1367.0
# 3                                 33.0                   1367.0
# 4                                 33.0                   1367.0
# ...                                ...                      ...
# 156513                           127.0                    638.0
# 156514                           105.0                    563.0
# 156515                            94.0                    462.0
# 156516                            82.0                    361.0
# 156517                            69.0                    332.0
#
#         daily_people_vaccinated_per_hundred
# 0                                       NaN
# 1                                     0.003
# 2                                     0.003
# 3                                     0.003
# 4                                     0.003
# ...                                     ...
# 156513                                0.004
# 156514                                0.003
# 156515                                0.003
# 156516                                0.002
# 156517                                0.002
#
# [156518 rows x 16 columns]

# %%
total_vaccinations_by_location = df.groupby('location')['total_vaccinations'].sum()

# %%
total_vaccinations_by_location
# Out:
# location
# Afghanistan          5.888728e+08
# Africa               2.651715e+11
# Albania              3.799607e+08
# Algeria              2.983973e+08
# Andorra              5.061072e+06
#                          ...
# Wallis and Futuna    4.837050e+05
# World                6.340245e+12
# Yemen                2.604640e+07
# Zambia               6.062863e+08
# Zimbabwe             3.211422e+09
# Name: total_vaccinations, Length: 235, dtype: float64

# %%
tf = total_vaccinations_by_location.reset_index().rename(columns={'total_vaccinations': 'total_vaccinations_by_location'})

# %%
tf
# Out:
#               location  total_vaccinations_by_location
# 0          Afghanistan                    5.888728e+08
# 1               Africa                    2.651715e+11
# 2              Albania                    3.799607e+08
# 3              Algeria                    2.983973e+08
# 4              Andorra                    5.061072e+06
# ..                 ...                             ...
# 230  Wallis and Futuna                    4.837050e+05
# 231              World                    6.340245e+12
# 232              Yemen                    2.604640e+07
# 233             Zambia                    6.062863e+08
# 234           Zimbabwe                    3.211422e+09
#
# [235 rows x 2 columns]

# %%
df = pd.read_csv('covid_worldwide.csv')
