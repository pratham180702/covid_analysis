# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# # Data Reading

# %%
df = pd.read_csv('covid_worldwide.csv')

# %%
df
# Out:
#      Serial Number           Country  Total Cases Total Deaths  \
# 0                1               USA  104,196,861    1,132,935
# 1                2             India   44,682,784      530,740
# 2                3            France   39,524,311      164,233
# 3                4           Germany   37,779,833      165,711
# 4                5            Brazil   36,824,580      697,074
# ..             ...               ...          ...          ...
# 226            227  Diamond Princess          712           13
# 227            228      Vatican City           29          NaN
# 228            229    Western Sahara           10            1
# 229            230        MS Zaandam            9            2
# 230            231           Tokelau            5          NaN
#
#     Total Recovered Active Cases     Total Test     Population
# 0       101,322,779    1,741,147  1,159,832,679    334,805,269
# 1        44,150,289        1,755    915,265,788  1,406,631,776
# ...

# %%
# checking how many values are null in Population column

null_count = df['Population'].isnull().sum()
print(null_count)
# Out:
# 3

# %%
# as csv file has china Population as Null so it will be removed during cleaning so checking it's index where it is
# and entering it's value manually

index = df.index[df['Country'] == 'China'][0]
index
# Out:
# 90

# %%
# details of index 90

df.iloc[90,:]
# Out:
# Serial Number               91
# Country                  China
# Total Cases            503,302
# Total Deaths             5,272
# Total Recovered        379,053
# Active Cases           118,977
# Total Test         160,000,000
# Population                 NaN
# Name: 90, dtype: object

# %%
# addind china's missing and wrong values
df.at[90, 'Population'] = '1,410,000,000'
df.at[90,'Total Test'] = '2,100,000,000'
df.at[90,'Total Cases'] = '2023378'
df.at[90,'Total Deaths'] = '87,468'
df.at[90,'Total Recovered'] = '1,935,910'

# %%
#removig countries with 0 population

df = df.dropna(subset=['Population'])
print(df)
# Out:
#      Serial Number         Country  Total Cases Total Deaths Total Recovered  \
# 0                1             USA  104,196,861    1,132,935     101,322,779
# 1                2           India   44,682,784      530,740      44,150,289
# 2                3          France   39,524,311      164,233      39,264,546
# 3                4         Germany   37,779,833      165,711      37,398,100
# 4                5          Brazil   36,824,580      697,074      35,919,372
# ..             ...             ...          ...          ...             ...
# 224            225      Montserrat        1,403            8           1,376
# 225            226            Niue          747          NaN             746
# 227            228    Vatican City           29          NaN              29
# 228            229  Western Sahara           10            1               9
# 230            231         Tokelau            5          NaN             NaN
#
# ...

# %%
df
# Out:
#      Serial Number         Country  Total Cases Total Deaths Total Recovered  \
# 0                1             USA  104,196,861    1,132,935     101,322,779
# 1                2           India   44,682,784      530,740      44,150,289
# 2                3          France   39,524,311      164,233      39,264,546
# 3                4         Germany   37,779,833      165,711      37,398,100
# 4                5          Brazil   36,824,580      697,074      35,919,372
# ..             ...             ...          ...          ...             ...
# 224            225      Montserrat        1,403            8           1,376
# 225            226            Niue          747          NaN             746
# 227            228    Vatican City           29          NaN              29
# 228            229  Western Sahara           10            1               9
# 230            231         Tokelau            5          NaN             NaN
#
# ...

# %%
# cross chekcking if all the countries with 0 population has been removed or not

null_count = df['Population'].isnull().sum()
print(null_count)
# Out:
# 0

# %%
null_count = df.isnull().sum()
print(null_count)
# Out:
# Serial Number       0
# Country             0
# Total Cases         0
# Total Deaths        6
# Total Recovered    21
# Active Cases       19
# Total Test         16
# Population          0
# dtype: int64

# %%
df = df.dropna()

# %%
df
# Out:
#      Serial Number                Country  Total Cases Total Deaths  \
# 0                1                    USA  104,196,861    1,132,935
# 1                2                  India   44,682,784      530,740
# 2                3                 France   39,524,311      164,233
# 3                4                Germany   37,779,833      165,711
# 4                5                 Brazil   36,824,580      697,074
# ..             ...                    ...          ...          ...
# 217            218               Anguilla        3,904           12
# 218            219                  Macao        3,488          120
# 219            220  Saint Pierre Miquelon        3,452            2
# 220            221      Wallis and Futuna        3,427            7
# 224            225             Montserrat        1,403            8
#
#     Total Recovered Active Cases     Total Test     Population
# 0       101,322,779    1,741,147  1,159,832,679    334,805,269
# ...

# %%
# df.plot(y=df['Total Cases'])
print(df.dtypes)
# Out:
# Serial Number       int64
# Country            object
# Total Cases        object
# Total Deaths       object
# Total Recovered    object
# Active Cases       object
# Total Test         object
# Population         object
# dtype: object

# %%
print(df['Total Cases'].unique())
# Out:
# ['104,196,861' '44,682,784' '39,524,311' '37,779,833' '36,824,580'
#  '32,588,442' '30,197,066' '25,453,789' '24,274,361' '21,958,696'
#  '13,731,478' '11,526,508' '11,295,446' '10,037,135' '9,569,611'
#  '8,582,500' '7,564,350' '7,368,252' '6,730,289' '6,380,225' '6,356,309'
#  '5,780,229' '5,708,301' '5,563,907' '5,370,131' '5,118,981' '5,036,593'
#  '4,786,189' '4,726,984' '4,691,499' '4,590,019' '4,550,256' '4,481,621'
#  '4,385,701' '4,073,454' '4,055,966' '3,325,006' '3,173,247' '2,877,280'
#  '2,693,458' '2,471,198' '2,465,545' '2,217,110' '2,192,447' '2,182,355'
#  '2,037,556' '1,860,893' '1,814,180' '1,746,997' '1,700,253' '1,576,313'
#  '1,477,856' '1,458,619' '1,405,917' '1,321,852' '1,296,865' '1,295,426'
#  '1,272,240' '1,267,580' '1,228,639' '1,227,853' '1,187,986' '1,186,176'
#  '1,112,438' '1,051,239' '1,049,409' '1,032,710' '1,029,701' '1,007,871'
#  '1,001,102' '994,037' '975,355' '827,962' '827,944' '700,452' '671,989'
# ...

# %%
# replacing all the comas in Total cases column

df['Total Cases'] = df['Total Cases'].replace(',', '', regex=True)
# Out:
# C:\Users\PRATHAM\AppData\Local\Temp\ipykernel_14928\4261526204.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Total Cases'] = df['Total Cases'].replace(',', '', regex=True)

# %%
# typecasting it to integer

df['Total Cases'] = df['Total Cases'].astype(int)
# Out:
# C:\Users\PRATHAM\AppData\Local\Temp\ipykernel_14928\2915380488.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Total Cases'] = df['Total Cases'].astype(int)

# %%
df['Total Cases']
# Out:
# 0      104196861
# 1       44682784
# 2       39524311
# 3       37779833
# 4       36824580
#          ...
# 217         3904
# 218         3488
# 219         3452
# 220         3427
# 224         1403
# Name: Total Cases, Length: 196, dtype: int32

# %%
# same for all the columns

print(df['Total Deaths'].unique())
# Out:
# ['1,132,935' '530,740' '164,233' '165,711' '697,074' '68,399' '33,486'
#  '186,833' '204,171' '395,108' '118,434' '43,186' '18,615' '130,421'
#  '16,356' '22,989' '144,749' '332,198' '160,817' '118,736' '142,486'
#  '21,689' '35,630' '26,022' '111,020' '63,812' '36,942' '12,193' '33,865'
#  '33,557' '42,312' '50,380' '218,931' '14,452' '65,802' '102,595' '67,576'
#  '8,145' '13,358' '23,246' '17,701' '25,375' '1,722' '48,677' '3,781'
#  '29,442' '20,946' '16,926' '14,122' '8,462' '30,640' '5,112' '8,639'
#  '13,695' '7,056' '9,545' '38,179' '16,296' '17,877' '10,790' '20,106'
#  '22,346' '9,158' '8,530' '35,942' '2,348' '7,609' '8,596' '2,179'
#  '12,020' '7,118' '6,218' '9,574' '10,085' '1,543' '16,828' '2,570'
#  '4,384' '1,287' '19,490' '5,404' '2,912' '11,953' '5,845' '24,613'
#  '6,437' '87,468' '7,572' '686' '919' '8,717' '16,255' '4,628' '9,638'
#  '5,688' '4,047' '3,595' '2,800' '1,133' '2,797' '225' '6,881' '3,155'
# ...

# %%
df['Total Deaths'] = df['Total Deaths'].replace(',', '', regex=True)
df['Total Deaths'] = df['Total Deaths'].astype(int)
# Out:
# C:\Users\PRATHAM\AppData\Local\Temp\ipykernel_14928\2933133082.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Total Deaths'] = df['Total Deaths'].replace(',', '', regex=True)
# C:\Users\PRATHAM\AppData\Local\Temp\ipykernel_14928\2933133082.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Total Deaths'] = df['Total Deaths'].astype(int)

# %%
df['Total Deaths']
# Out:
# 0      1132935
# 1       530740
# 2       164233
# 3       165711
# 4       697074
#         ...
# 217         12
# 218        120
# 219          2
# 220          7
# 224          8
# Name: Total Deaths, Length: 196, dtype: int32

# %%
import matplotlib.pyplot as plt

plt.plot(df.index, df['Total Cases'])
plt.xlabel('index')
plt.ylabel('Total Cases')
plt.show()

# %%
df['Total Recovered'] = df['Total Recovered'].replace(',', '', regex=True)
df['Total Recovered'] = df['Total Recovered'].astype(int)

df['Active Cases'] = df['Active Cases'].replace(',', '', regex=True)
df['Active Cases'] = df['Active Cases'].astype(int)

df['Total Test'] = df['Total Test'].replace(',', '', regex=True)
df['Total Test'] = df['Total Test'].astype(int)

df['Population'] = df['Population'].replace(',', '', regex=True)
df['Population'] = df['Population'].astype(int)
# Out:
# C:\Users\PRATHAM\AppData\Local\Temp\ipykernel_14928\374402339.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Total Recovered'] = df['Total Recovered'].replace(',', '', regex=True)
# C:\Users\PRATHAM\AppData\Local\Temp\ipykernel_14928\374402339.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Total Recovered'] = df['Total Recovered'].astype(int)
# C:\Users\PRATHAM\AppData\Local\Temp\ipykernel_14928\374402339.py:4: SettingWithCopyWarning:
# ...

# %%
df
# Out:
#      Serial Number                Country  Total Cases  Total Deaths  \
# 0                1                    USA    104196861       1132935
# 1                2                  India     44682784        530740
# 2                3                 France     39524311        164233
# 3                4                Germany     37779833        165711
# 4                5                 Brazil     36824580        697074
# ..             ...                    ...          ...           ...
# 217            218               Anguilla         3904            12
# 218            219                  Macao         3488           120
# 219            220  Saint Pierre Miquelon         3452             2
# 220            221      Wallis and Futuna         3427             7
# 224            225             Montserrat         1403             8
#
#      Total Recovered  Active Cases  Total Test  Population
# 0          101322779       1741147  1159832679   334805269
# ...

# %%
df = df.sort_values('Total Cases',ascending=False)
df
# Out:
#      Serial Number                Country  Total Cases  Total Deaths  \
# 0                1                    USA    104196861       1132935
# 1                2                  India     44682784        530740
# 2                3                 France     39524311        164233
# 3                4                Germany     37779833        165711
# 4                5                 Brazil     36824580        697074
# ..             ...                    ...          ...           ...
# 217            218               Anguilla         3904            12
# 218            219                  Macao         3488           120
# 219            220  Saint Pierre Miquelon         3452             2
# 220            221      Wallis and Futuna         3427             7
# 224            225             Montserrat         1403             8
#
#      Total Recovered  Active Cases  Total Test  Population
# 0          101322779       1741147  1159832679   334805269
# ...

# %%
df.iloc[90,:]
# Out:
# Serial Number           96
# Country            Armenia
# Total Cases         446008
# Total Deaths          8717
# Total Recovered     435162
# Active Cases          2129
# Total Test         3242901
# Population         2971966
# Name: 95, dtype: object

# %%
# considering only top 50 countries based on the total number of cases

df = df[:50]
df
# Out:
#     Serial Number       Country  Total Cases  Total Deaths  Total Recovered  \
# 0               1           USA    104196861       1132935        101322779
# 1               2         India     44682784        530740         44150289
# 2               3        France     39524311        164233         39264546
# 3               4       Germany     37779833        165711         37398100
# 4               5        Brazil     36824580        697074         35919372
# 5               6         Japan     32588442         68399         21567425
# 6               7      S. Korea     30197066         33486         29740877
# 7               8         Italy     25453789        186833         25014986
# 8               9            UK     24274361        204171         24020088
# 9              10        Russia     21958696        395108         21356008
# 11             12         Spain     13731478        118434         13557699
# ...

# %%
import matplotlib.pyplot as plt

plt.plot(df['Total Recovered'], df['Total Cases'])
plt.xlabel('index')
plt.ylabel('Total Cases')
plt.show()

# %% [markdown]
# # Logic Implementation
# ### if(% of population got +ve by covid is very high)
# ### and
# ### % of recovered is as high as possible
# ### and
# ### Tests conducted on population is more than 100%(each person is tested atleast once)
#
# ## then that country has given tough fight to covid

# %%
# calculating the percent affected by covid of the total population

df['percent_affected'] = df['Total Cases'] / df['Population'] * 100
# Out:
# C:\Users\PRATHAM\AppData\Local\Temp\ipykernel_14928\1802416975.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['percent_affected'] = df['Total Cases'] / df['Population'] * 100

# %%
df
# Out:
#     Serial Number       Country  Total Cases  Total Deaths  Total Recovered  \
# 0               1           USA    104196861       1132935        101322779
# 1               2         India     44682784        530740         44150289
# 2               3        France     39524311        164233         39264546
# 3               4       Germany     37779833        165711         37398100
# 4               5        Brazil     36824580        697074         35919372
# 5               6         Japan     32588442         68399         21567425
# 6               7      S. Korea     30197066         33486         29740877
# 7               8         Italy     25453789        186833         25014986
# 8               9            UK     24274361        204171         24020088
# 9              10        Russia     21958696        395108         21356008
# 11             12         Spain     13731478        118434         13557699
# ...

# %%
# calculating the percent recovered out of these affected people

df['percent_recovered'] = df['Total Recovered']/df['Total Cases'] * 100
df.head(5)
# Out:
# C:\Users\PRATHAM\AppData\Local\Temp\ipykernel_14928\22595710.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['percent_recovered'] = df['Total Recovered']/df['Total Cases'] * 100
#    Serial Number  Country  Total Cases  Total Deaths  Total Recovered  \
# 0              1      USA    104196861       1132935        101322779
# 1              2    India     44682784        530740         44150289
# 2              3   France     39524311        164233         39264546
# 3              4  Germany     37779833        165711         37398100
# 4              5   Brazil     36824580        697074         35919372
#
#    Active Cases  Total Test  Population  percent_affected  percent_recovered
# ...

# %%
# calculating the percent of people tested for covid out of total population

# df['percent_tested'] = df['Total Test']/df['Population']*100
# df

# %%
# Sort the DataFrame by the percent_affected column in ascending order

df_sorted = df.sort_values('percent_affected')

# %%
df_sorted.head()
# Out:
#     Serial Number      Country  Total Cases  Total Deaths  Total Recovered  \
# 90             91        China      2023378         87468          1935910
# 47             48   Bangladesh      2037556         29442          1992694
# 19             20    Indonesia      6730289        160817          6565208
# 1               2        India     44682784        530740         44150289
# 36             37  Philippines      4073454         65802          3998048
#
#     Active Cases  Total Test  Population  percent_affected  percent_recovered
# 90        118977  2100000000  1410000000          0.143502          95.677130
# 47         15420    15247014   167885689          1.213657          97.798245
# 19          4264   114158919   279134505          2.411128          97.547193
# 1           1755   915265788  1406631776          3.176580          98.808277
# 36          9604    34343332   112508994          3.620559          98.148844

# %%
plt.scatter(df['percent_affected'],df['percent_recovered'])

# %%
# setting a new index

df_sorted = df_sorted.set_index(np.arange(50))

# %%
df_sorted.head()
# Out:
#    Serial Number      Country  Total Cases  Total Deaths  Total Recovered  \
# 0             91        China      2023378         87468          1935910
# 1             48   Bangladesh      2037556         29442          1992694
# 2             20    Indonesia      6730289        160817          6565208
# 3              2        India     44682784        530740         44150289
# 4             37  Philippines      4073454         65802          3998048
#
#    Active Cases  Total Test  Population  percent_affected  percent_recovered
# 0        118977  2100000000  1410000000          0.143502          95.677130
# 1         15420    15247014   167885689          1.213657          97.798245
# 2          4264   114158919   279134505          2.411128          97.547193
# 3          1755   915265788  1406631776          3.176580          98.808277
# 4          9604    34343332   112508994          3.620559          98.148844

# %%
df_sorted['Serial Number'] = df_sorted['Serial Number'].astype(int)

# %%
df_sorted.head(5)
# Out:
#    Serial Number      Country  Total Cases  Total Deaths  Total Recovered  \
# 0             91        China      2023378         87468          1935910
# 1             48   Bangladesh      2037556         29442          1992694
# 2             20    Indonesia      6730289        160817          6565208
# 3              2        India     44682784        530740         44150289
# 4             37  Philippines      4073454         65802          3998048
#
#    Active Cases  Total Test  Population  percent_affected  percent_recovered
# 0        118977  2100000000  1410000000          0.143502          95.677130
# 1         15420    15247014   167885689          1.213657          97.798245
# 2          4264   114158919   279134505          2.411128          97.547193
# 3          1755   915265788  1406631776          3.176580          98.808277
# 4          9604    34343332   112508994          3.620559          98.148844

# %%
# out of all the countries selecting those whose serial number is < 10 means they are in top 10 for total number of cases

df1 = df_sorted[df_sorted['Serial Number'] <= 10]

# %%
df1
# Out:
#     Serial Number   Country  Total Cases  Total Deaths  Total Recovered  \
# 3               2     India     44682784        530740         44150289
# 15             10    Russia     21958696        395108         21356008
# 19              5    Brazil     36824580        697074         35919372
# 23              6     Japan     32588442         68399         21567425
# 28              1       USA    104196861       1132935        101322779
# 30              9        UK     24274361        204171         24020088
# 35              8     Italy     25453789        186833         25014986
# 39              4   Germany     37779833        165711         37398100
# 47              7  S. Korea     30197066         33486         29740877
# 48              3    France     39524311        164233         39264546
#
#     Active Cases  Total Test  Population  percent_affected  percent_recovered
# 3           1755   915265788  1406631776          3.176580          98.808277
# ...

# %%
# final cleaning of dataset

df_final = df1[['Serial Number','Country','percent_affected','percent_recovered','Population']]

# %%
df_final
# Out:
#     Serial Number   Country  percent_affected  percent_recovered  Population
# 3               2     India          3.176580          98.808277  1406631776
# 15             10    Russia         15.060220          97.255356   145805947
# 19              5    Brazil         17.099589          97.541838   215353593
# 23              6     Japan         25.949344          66.181209   125584838
# 28              1       USA         31.121631          97.241681   334805269
# 30              9        UK         35.438106          98.952504    68497907
# 35              8     Italy         42.238000          98.276080    60262770
# 39              4   Germany         45.038404          98.989585    83883596
# 47              7  S. Korea         58.829389          98.489294    51329899
# 48              3    France         60.264697          99.342772    65584518

# %% [markdown]
# # Data of Total conducted tested per 1000

# %%
tests_df = pd.read_csv('full-list-cumulative-total-tests-per-thousand.csv')

# %%
tests_df
# Out:
#             Entity Code         Day  total_tests_per_thousand  \
# 0      Afghanistan  AFG  2022-01-29                    21.272
# 1      Afghanistan  AFG  2022-02-26                    22.181
# 2      Afghanistan  AFG  2022-03-12                    22.545
# 3      Afghanistan  AFG  2022-05-24                    24.485
# 4      Afghanistan  AFG  2022-06-23                    24.811
# ...            ...  ...         ...                       ...
# 79382     Zimbabwe  ZWE  2022-06-08                   147.013
# 79383     Zimbabwe  ZWE  2022-06-12                   147.536
# 79384     Zimbabwe  ZWE  2022-06-16                   147.917
# 79385     Zimbabwe  ZWE  2022-06-20                   148.454
# 79386     Zimbabwe  ZWE  2022-06-22                   148.804
#
#       142605-annotations
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ...                  ...
# 79382    tests performed
# ...

# %%
# data is given on the daily basis, so we have to find the mean tests/1000 for each country
# group_by returns a Series so to_frame() converts the series into dataframe
# reset_index() will reset the index of the datafram

grouped_tests_df = tests_df.groupby("Entity")["total_tests_per_thousand"].mean().to_frame().reset_index()

# %%
# round(2) will round off the value to 2 decimal places(.2f)

grouped_tests_df["total_tests_per_thousand"] = grouped_tests_df["total_tests_per_thousand"].round(2)
grouped_tests_df
# Out:
#              Entity  total_tests_per_thousand
# 0       Afghanistan                     23.06
# 1           Albania                    196.04
# 2           Algeria                      5.22
# 3           Andorra                   2296.43
# 4            Angola                     41.40
# ..              ...                       ...
# 183         Vietnam                    718.94
# 184  Western Sahara                      6.97
# 185           Yemen                     10.10
# 186          Zambia                     80.44
# 187        Zimbabwe                     43.95
#
# [188 rows x 2 columns]

# %%
# renaming

grouped_tests_df = grouped_tests_df.reset_index().rename(columns={'Entity': 'Country'})

# %%
index = grouped_tests_df.index[grouped_tests_df['Country'] == 'United States'][0]
index
# Out:
# 179

# %%
index = grouped_tests_df.index[grouped_tests_df['Country'] == 'United Kingdom'][0]
index
# Out:
# 178

# %%
index = grouped_tests_df.index[grouped_tests_df['Country'] == 'South Korea'][0]
index
# Out:
# 158

# %%
# changing the names of the countries to make it compatible with df_sorted to
# FROM United States to USA
# FROM United Kingdom to UK
# FROM South Korea to S. Korea

grouped_tests_df.at[179,'Country']='USA'

grouped_tests_df.at[178,'Country']='UK'

grouped_tests_df.at[158,'Country']='S. Korea'

# %%
# merging

merge_df = pd.merge(df_final, grouped_tests_df , on='Country')
merge_df
# Out:
#    Serial Number   Country  percent_affected  percent_recovered  Population  \
# 0              2     India          3.176580          98.808277  1406631776
# 1             10    Russia         15.060220          97.255356   145805947
# 2              5    Brazil         17.099589          97.541838   215353593
# 3              6     Japan         25.949344          66.181209   125584838
# 4              1       USA         31.121631          97.241681   334805269
# 5              9        UK         35.438106          98.952504    68497907
# 6              8     Italy         42.238000          98.276080    60262770
# 7              4   Germany         45.038404          98.989585    83883596
# 8              7  S. Korea         58.829389          98.489294    51329899
# 9              3    France         60.264697          99.342772    65584518
#
#    index  total_tests_per_thousand
# 0     84                    260.04
# 1    144                    687.98
# ...

# %%
# calculating %

merge_df['percent_tested_per_1000'] = merge_df['total_tests_per_thousand'] * 0.1

# %%
merge_df
# Out:
#    Serial Number   Country  percent_affected  percent_recovered  Population  \
# 0              2     India          3.176580          98.808277  1406631776
# 1             10    Russia         15.060220          97.255356   145805947
# 2              5    Brazil         17.099589          97.541838   215353593
# 3              6     Japan         25.949344          66.181209   125584838
# 4              1       USA         31.121631          97.241681   334805269
# 5              9        UK         35.438106          98.952504    68497907
# 6              8     Italy         42.238000          98.276080    60262770
# 7              4   Germany         45.038404          98.989585    83883596
# 8              7  S. Korea         58.829389          98.489294    51329899
# 9              3    France         60.264697          99.342772    65584518
#
#    index  total_tests_per_thousand  percent_tested_per_1000
# 0     84                    260.04                   26.004
# ...

# %%
# picking required variables

df_final = merge_df[['Serial Number','Country','percent_affected','percent_tested_per_1000','percent_recovered','Population']]

# %% [markdown]
# # Also considering the fully vaccinated percentage

# %%
df_final
# Out:
#    Serial Number   Country  percent_affected  percent_tested_per_1000  \
# 0              2     India          3.176580                   26.004
# 1             10    Russia         15.060220                   68.798
# 2              5    Brazil         17.099589                   15.953
# 3              6     Japan         25.949344                   12.445
# 4              1       USA         31.121631                  121.777
# 5              9        UK         35.438106                  275.865
# 6              8     Italy         42.238000                  125.956
# 7              4   Germany         45.038404                   67.351
# 8              7  S. Korea         58.829389                   46.545
# 9              3    France         60.264697                  160.917
#
#    percent_recovered  Population
# 0          98.808277  1406631776
# 1          97.255356   145805947
# 2          97.541838   215353593
# 3          66.181209   125584838
# ...

# %%
df_vacc = pd.read_csv('current-global.csv')

# %%
df_vacc.head(-50)
# Out:
#       id  population         name  dosesAdministered  peopleVaccinated  \
# 0    ABW    111000.0        Aruba             173365           89790.0
# 1    AFG  32941000.0  Afghanistan           11820186        10873999.0
# 2    AGO  31031000.0       Angola           22297104        14220830.0
# 3    AIA     15000.0     Anguilla              24102           10846.0
# 4    ALB   2878000.0      Albania            2966256         1335654.0
# ..   ...         ...          ...                ...               ...
# 168  POL  37958000.0       Poland           56434282        22867361.0
# 169  PRT  10310000.0     Portugal           24899865         9751756.0
# 170  PRY   7253000.0     Paraguay            9386134         3986965.0
# 171  QAT   2684000.0        Qatar            7464349         2795446.0
# 172  ROU  19329000.0      Romania           16827486         8181513.0
#
#      completedVaccination  boosterDosesAdministered
# 0                 83575.0                       NaN
# ...

# %%
index = df_vacc.index[df_vacc['name'] == 'US'][0]
index
# Out:
# 212

# %%
df_vacc.at[212,'name']='USA'

# %%
index = df_vacc.index[df_vacc['name'] == 'South Korea'][0]
index
# Out:
# 122

# %%
df_vacc.at[122,'name']='S. Korea'

# %%
df_vacc1 = df_vacc.reset_index().rename(columns={'name': 'Country'})

# %%
df_vacc1.head(5)
# Out:
#    index   id  population      Country  dosesAdministered  peopleVaccinated  \
# 0      0  ABW    111000.0        Aruba             173365           89790.0
# 1      1  AFG  32941000.0  Afghanistan           11820186        10873999.0
# 2      2  AGO  31031000.0       Angola           22297104        14220830.0
# 3      3  AIA     15000.0     Anguilla              24102           10846.0
# 4      4  ALB   2878000.0      Albania            2966256         1335654.0
#
#    completedVaccination  boosterDosesAdministered
# 0               83575.0                       NaN
# 1            10105500.0                       NaN
# 2             7814121.0                 1127156.0
# 3               10314.0                    2942.0
# 4             1261243.0                  352685.0

# %%
df_vacc2 = df_vacc1[['Country','completedVaccination']]
df_vacc2
# Out:
#           Country  completedVaccination
# 0           Aruba               83575.0
# 1     Afghanistan            10105500.0
# 2          Angola             7814121.0
# 3        Anguilla               10314.0
# 4         Albania             1261243.0
# ..            ...                   ...
# 218         Samoa              177456.0
# 219         Yemen              470491.0
# 220  South Africa            19377183.0
# 221        Zambia             5926723.0
# 222      Zimbabwe             5912093.0
#
# [223 rows x 2 columns]

# %%
vacc_merged_df = pd.merge(df_final, df_vacc2 , on='Country')
vacc_merged_df
# Out:
#    Serial Number   Country  percent_affected  percent_tested_per_1000  \
# 0              2     India          3.176580                   26.004
# 1             10    Russia         15.060220                   68.798
# 2              5    Brazil         17.099589                   15.953
# 3              6     Japan         25.949344                   12.445
# 4              1       USA         31.121631                  121.777
# 5              9        UK         35.438106                  275.865
# 6              8     Italy         42.238000                  125.956
# 7              4   Germany         45.038404                   67.351
# 8              7  S. Korea         58.829389                   46.545
# 9              3    France         60.264697                  160.917
#
#    percent_recovered  Population  completedVaccination
# 0          98.808277  1406631776           946810471.0
# 1          97.255356   145805947            76695743.0
# ...

# %%
# vacc_merged_df['fully_vaccinated'] = vacc_merged_df['completedVaccination']/10000000

# %%
vacc_merged_df
# Out:
#    Serial Number   Country  percent_affected  percent_tested_per_1000  \
# 0              2     India          3.176580                   26.004
# 1             10    Russia         15.060220                   68.798
# 2              5    Brazil         17.099589                   15.953
# 3              6     Japan         25.949344                   12.445
# 4              1       USA         31.121631                  121.777
# 5              9        UK         35.438106                  275.865
# 6              8     Italy         42.238000                  125.956
# 7              4   Germany         45.038404                   67.351
# 8              7  S. Korea         58.829389                   46.545
# 9              3    France         60.264697                  160.917
#
#    percent_recovered  Population  completedVaccination
# 0          98.808277  1406631776           946810471.0
# 1          97.255356   145805947            76695743.0
# ...

# %%
vacc_merged_df['percent_fully_vacc'] = vacc_merged_df['completedVaccination']/vacc_merged_df['Population'] * 100
vacc_merged_df
# Out:
#    Serial Number   Country  percent_affected  percent_tested_per_1000  \
# 0              2     India          3.176580                   26.004
# 1             10    Russia         15.060220                   68.798
# 2              5    Brazil         17.099589                   15.953
# 3              6     Japan         25.949344                   12.445
# 4              1       USA         31.121631                  121.777
# 5              9        UK         35.438106                  275.865
# 6              8     Italy         42.238000                  125.956
# 7              4   Germany         45.038404                   67.351
# 8              7  S. Korea         58.829389                   46.545
# 9              3    France         60.264697                  160.917
#
#    percent_recovered  Population  completedVaccination  percent_fully_vacc
# 0          98.808277  1406631776           946810471.0           67.310471
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# create a plot with custom parameters
fig, ax = plt.subplots(figsize=(8, 6), dpi=100)

# add the first scatter plot to the graph
vacc_merged_df.plot('percent_affected', 'percent_recovered',  c='blue', marker='o', ax=ax)

# add the second scatter plot to the graph
vacc_merged_df.plot('percent_affected', 'percent_tested_per_1000', c='red', marker='s', ax=ax)

#adding third plot
vacc_merged_df.plot('percent_affected', 'percent_fully_vacc', c='green', marker='p', ax=ax)

# add text labels and dotted line for each data point
for i, row in vacc_merged_df.iterrows():
    if row['Country'] in ['Brazil', 'Italy', 'France']:
        ax.text(row['percent_affected'] , row['percent_recovered'] - 10, f"{row['percent_recovered']:.2f}", fontsize=10)
        ax.text(row['percent_affected'] + 0.5, row['percent_tested_per_1000'], row['Country'], fontsize=10)
        ax.vlines(row['percent_affected'], 0, row['percent_tested_per_1000'], linestyle='dotted', alpha=0.5,color='red')
    else:
        ax.text(row['percent_affected'] - 2.5, row['percent_recovered'] + 5, f"{row['percent_recovered']:.2f}", fontsize=10)
        ax.text(row['percent_affected'] + 1, row['percent_tested_per_1000'], row['Country'], fontsize=10)
        ax.vlines(row['percent_affected'], 0, row['percent_tested_per_1000'], linestyle='dotted', alpha=0.5,color='red')

# set plot labels and title
ax.set_xlabel('Percent Affected')
ax.set_ylabel('Percent Recovered ,Tested/1000 & Fully vaccinated')
ax.set_title('COVID-19 Recovery and Testing Rates by Country(based on total cases)')

# display the plot
plt.show()

# %%
# logic implementation

new_vacc_df = vacc_merged_df[vacc_merged_df['percent_recovered']>98]


new_vacc_df = new_vacc_df[vacc_merged_df['percent_tested_per_1000']>=100]
# Out:
# C:\Users\PRATHAM\AppData\Local\Temp\ipykernel_14928\1277191654.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   new_vacc_df = new_vacc_df[vacc_merged_df['percent_tested_per_1000']>=100]

# %%
new_vacc_df
# Out:
#    Serial Number Country  percent_affected  percent_tested_per_1000  \
# 5              9      UK         35.438106                  275.865
# 6              8   Italy         42.238000                  125.956
# 9              3  France         60.264697                  160.917
#
#    percent_recovered  Population  completedVaccination  percent_fully_vacc
# 5          98.952504    68497907            44025448.0           64.272691
# 6          98.276080    60262770            47964984.0           79.593062
# 9          99.342772    65584518            53053657.0           80.893569

# %%
import pandas as pd
import matplotlib.pyplot as plt

# create a plot with custom parameters
fig, ax = plt.subplots(figsize=(8, 6), dpi=100)

# add the first scatter plot to the graph
new_vacc_df.plot('percent_affected', 'percent_recovered',  c='blue', marker='o', ax=ax)

# add the second scatter plot to the graph
new_vacc_df.plot('percent_affected', 'percent_tested_per_1000', c='red', marker='s', ax=ax)

#adding third plot
new_vacc_df.plot('percent_affected', 'percent_fully_vacc', c='green', marker='p', ax=ax)

# add text labels and dotted line for each data point
for i, row in new_vacc_df.iterrows():
#     if row['Country'] in ['Brazil', 'Italy', 'France']:
    ax.text(row['percent_affected'] , row['percent_recovered']+10, f"{row['percent_recovered']:.2f}", fontsize=10)
    ax.text(row['percent_affected'] + 0.5, row['percent_tested_per_1000'], row['Country'], fontsize=10)
    ax.text(row['percent_affected'] + 0.25, row['percent_fully_vacc']-10, f"{row['percent_fully_vacc']:.2f}", fontsize=10)
    ax.vlines(row['percent_affected'], 0, row['percent_tested_per_1000'], linestyle='dotted', alpha=0.5,color='red')
  

# set plot labels and title
ax.set_xlabel('Percent Affected')
ax.set_ylabel('Percent Recovered ,Tested/1000 & Fully vaccinated')
ax.set_title('COVID-19 Recovery and Testing Rates by Country(based on total cases)')

# display the plot
plt.show()

# %% [markdown]
# # Conclusion:
# ### UK, Italy and France has performed well, considering the logic and Total number of cases
